# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikreddy1335/RL-1335/blob/main/Assignment_lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()

print("CliffWalking Environment")
random_agent("CliffWalking-v1", 5)

print("Taxi Environment")
random_agent("Taxi-v4", 5)
# Out:
# CliffWalking Environment
# Episode: 1
# Total Reward: -27679
# Average Reward: -9.78
#
# Episode: 2
# Total Reward: -155120
# Average Reward: -10.18
#
# Episode: 3
# Total Reward: -83741
# Average Reward: -10.33
#
# Episode: 4
# Total Reward: -161517
# Average Reward: -10.63
#
# Episode: 5
# Total Reward: -39268
# Average Reward: -10.82
#
# Taxi Environment
# Episode: 1
# Total Reward: -785
# Average Reward: -3.92
#
# Episode: 2
# Total Reward: -785
# Average Reward: -3.92
#
# Episode: 3
# Total Reward: -821
# Average Reward: -4.11
#
# Episode: 4
# Total Reward: -704
# Average Reward: -3.52
#
# Episode: 5
# Total Reward: -668
# Average Reward: -3.34
